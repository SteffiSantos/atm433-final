# %% [markdown]
# # [WIP -- IGNORE] NAO Project, Part 2

# %% [markdown]
# ## Imports

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import geopandas as gp
import pandas as pd
from metpy.plots import USCOUNTIES
import contextily as ctx
import matplotlib.pyplot as plt
from ipyleaflet import Map, TileLayer, basemaps, basemap_to_tiles
from ipyleaflet.velocity import Velocity

# %%
natlantic = [-80,5,20,70]
natlantic
# Out:
# [-80, 5, 20, 70]

# %%
ctx.providers.keys()
# Out:
# dict_keys(['OpenStreetMap', 'OpenSeaMap', 'OpenPtMap', 'OpenTopoMap', 'OpenRailwayMap', 'OpenFireMap', 'SafeCast', 'Thunderforest', 'OpenMapSurfer', 'Hydda', 'MapBox', 'Stamen', 'Esri', 'OpenWeatherMap', 'HERE', 'FreeMapSK', 'MtbMap', 'CartoDB', 'HikeBike', 'BasemapAT', 'nlmaps', 'NASAGIBS', 'NLS', 'JusticeMap', 'Wikimedia', 'GeoportailFrance', 'OneMapSG'])

# %%
ctx.providers.Wikimedia
# Out:
# {'url': 'https://maps.wikimedia.org/osm-intl/{z}/{x}/{y}{r}.png',
#  'attribution': 'Wikimedia',
#  'min_zoom': 1,
#  'max_zoom': 19,
#  'name': 'Wikimedia'}

# %%
fig = plt.figure(figsize=(20,10))
ax = plt.axes(projection=ccrs.epsg('3857'))

#my chosen basemap is OpenSeaMap!
wiki = ctx.providers.Wikimedia

res='50m'
plt.title('Map of North Atlantic Ocean')
ax.coastlines(resolution=res)

ax.set_extent(natlantic, ccrs.PlateCarree())
ctx.add_basemap(ax,source=wiki)
plt.show()

# %%
m=Map()

# %%
timeObj = datetime(2021,10,27,12)
timeStr1 = timeObj.strftime("%Y-%m-%d")
timeStr2 = timeObj.strftime("%Y%m%d_%H%M")
