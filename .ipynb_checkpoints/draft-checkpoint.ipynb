# %% [markdown]
# ## ATM433 Final Project: Effects of Winter North Atlantic Oscillation

# %% [markdown]
# ## Imports

# %%
import xarray as xr
import pandas as pd
import geopandas
import numpy as np
import seaborn

from datetime import datetime as dt
from metpy.units import units
from metpy import calc as mpcalc
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import requests
from pathlib import Path

import statistics

# %% [markdown]
# ## North Atlantic Oscillation

# %% [markdown]
# Data taken from NOAA https://www.ncdc.noaa.gov/teleconnections/nao/
#
# First, I get my data from NOAA site; data is given in ASCII table form, so I convert to a DataFrame

# %%
NAO_url ='https://www.cpc.ncep.noaa.gov/products/precip/CWlink/pna/norm.nao.monthly.b5001.current.ascii.table'
dfNAO = pd.read_table(NAO_url, sep="\s+") #NAO DataFrame
dfNAO
# Out:
#     1950  0.92  0.40  -0.36  0.73  -0.59  -0.06  -1.26  -0.05  0.25  0.85  \
# 0   1951  0.08  0.70  -1.02 -0.22  -0.59  -1.64   1.37  -0.22 -1.36  1.87
# 1   1952  0.93 -0.83  -1.49  1.01  -1.12  -0.40  -0.09  -0.28 -0.54 -0.73
# 2   1953  0.33 -0.49  -0.04 -1.67  -0.66   1.09   0.40  -0.71 -0.35  1.32
# 3   1954  0.37  0.74  -0.83  1.34  -0.09  -0.25  -0.60  -1.90 -0.44  0.60
# 4   1955 -1.84 -1.12  -0.53 -0.42  -0.34  -1.10   1.76   1.07  0.32 -1.47
# ..   ...   ...   ...    ...   ...    ...    ...    ...    ...   ...   ...
# 66  2017  0.48  1.00   0.74  1.73  -1.91   0.05   1.26  -1.10 -0.61  0.19
# 67  2018  1.44  1.58  -0.93  1.24   2.12   1.09   1.39   1.97  1.67  0.93
# 68  2019  0.59  0.29   1.23  0.47  -2.62  -1.09  -1.43  -1.17 -0.16 -1.41
# 69  2020  1.34  1.26   1.01 -1.02  -0.41  -0.15  -1.23   0.12  0.98 -0.65
# 70  2021 -1.11  0.14   0.73 -1.43  -1.24   0.77   0.03  -0.28 -0.21 -2.29
#
#     -1.26.1  -1.02
# 0     -0.39   1.32
# 1     -1.13  -0.43
# 2      1.04  -0.47
# 3      0.40   0.69
# 4     -1.29   0.17
# ..      ...    ...
# 66    -0.00   0.88
# 67    -0.11   0.61
# 68     0.28   1.20
# 69     2.54  -0.30
# 70    -0.18    NaN
#
# [71 rows x 13 columns]

# %% [markdown]
# Since the top row is treating the first row of data (from 1950) as column labels, I'm going to manually replace them using .rename() -- I tried many other methods of doing this, and this, although a little tedious, was the only one that worked. Also, I'm going to subset the data anyway, so no worries about losing data from 1950.

# %%
dfNAO.columns
# Out:
# Index(['1950', '0.92', '0.40', '-0.36', '0.73', '-0.59', '-0.06', '-1.26',
#        '-0.05', '0.25', '0.85', '-1.26.1', '-1.02'],
#       dtype='object')

# %%
dfNAO=dfNAO.rename({'1950':'Year','0.92':'Jan', '0.40':'Feb', '-0.36':'Mar', '0.73':'Apr', '-0.59':'May', '-0.06':'Jun', '-1.26':'Jul', '-0.05':'Aug', '0.25':'Sep', '0.85':'Oct', '-1.26.1':'Nov', '-1.02':'Dec' }, axis='columns')

# %% [markdown]
# Since the data is taken by year, I'm going to shift the December column up by one, so that the values for each row represent a season instead of a year.

# %%
dfNAO.Dec = dfNAO.Dec.shift(1)

# %% [markdown]
# Subsetting data for just the 2000s winter seasons, for more clarity

# %%
dfNAO=dfNAO.iloc[49:71]

# %%
columns = ['Year','Dec','Jan','Feb']

dfNAO = pd.DataFrame(dfNAO, columns=columns)
dfNAO
# Out:
#     Year   Dec   Jan   Feb
# 49  2000  1.61  0.60  1.70
# 50  2001 -0.58  0.25  0.45
# 51  2002 -0.83  0.44  1.10
# 52  2003 -0.94  0.16  0.62
# 53  2004  0.64 -0.29 -0.14
# 54  2005  1.21  1.52 -0.06
# 55  2006 -0.44  1.27 -0.51
# 56  2007  1.34  0.22 -0.47
# 57  2008  0.34  0.89  0.73
# 58  2009 -0.28 -0.01  0.06
# 59  2010 -1.93 -1.11 -1.98
# 60  2011 -1.85 -0.88  0.70
# 61  2012  2.52  1.17  0.42
# 62  2013  0.17  0.35 -0.45
# 63  2014  0.95  0.29  1.34
# 64  2015  1.86  1.79  1.32
# 65  2016  2.24  0.12  1.58
# 66  2017  0.48  0.48  1.00
# 67  2018  0.88  1.44  1.58
# 68  2019  0.61  0.59  0.29
# 69  2020  1.20  1.34  1.26
# 70  2021 -0.30 -1.11  0.14

# %% [markdown]
# ### [SCRAPPED] NAO Visualization: Group Bar Chart
#
# #### This was my first approach to creating a group bar chart. Keeping everything as Markdown cells, just to have as reference.

# %% [markdown]
# Set labels; created an empty list called "labels", used a for loop to turn Years column data into a list for my x-axis labels. Also created several SERIES for the months of december, january, and february. I'm only interested in data for the Winter, so I picked these months to make the graph less populated.

# %% [markdown]
# labels=[]
# for x in dfNAO['Year']:
#     labels.append(str(x))
#
# #creates TUPLES
# dec_tup=dfNAO['Dec']
# jan_tup=dfNAO['Jan']
# feb_tup=dfNAO['Feb']
#
# #Turn into ARRAYS
# dec = np.asarray(dec_tup)
# jan = np.asarray(jan_tup)
# feb = np.asarray(feb_tup)

# %% [markdown]
# Used the matplotlib gallery for guidance in creating a grouped bar chart: https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html

# %% [markdown]
# index = np.arange(len(labels))
# index
#
# width=0.30
#
# fig, ax = plt.subplots()
# dec_plot = ax.bar(x-0.15, dec, width, label="Dec")
# jan_plot = ax.bar(x, jan, width, label="Jan")
# feb_plot = ax.bar(x+0.15, feb, width, label="Feb")
#
# fig.tight_layout()

# %% [markdown]
# ### NAO VISUALIZATION: Group Bar Chart and Multiline Connected Point Chart

# %% [markdown]
# Instead of creating series objects to plot my graph (like I tried above), I plotted the dfNAO dataframe directly. My reference: https://www.geeksforgeeks.org/create-a-grouped-bar-plot-in-matplotlib/
#
# It is a long line, but I like that plotting a DataFrame directly is fairly straightforward, and can be done in just one method.

# %%
plt.style.use('seaborn')

# %%
dfNAO.plot(x='Year', kind='bar', figsize=(18,12), stacked=False, title="Winter North Atlantic Oscillation (2000-2021)", ylabel="NAO Index", fontsize=12, colormap='winter')
# Out:
# <AxesSubplot:title={'center':'Winter North Atlantic Oscillation (2000-2021)'}, xlabel='Year', ylabel='NAO Index'>

# %% [markdown]
# Notice my use of the Winter colormap :)

# %% [markdown]
# Below is another supplementary graph to help illustrate NAO Indices in the 2010s.

# %%
fig, ax = plt.subplots(figsize = (18,12))

#plt.gca().set_prop_cycle(['cyan','magenta','darkpurple'])

for months in dfNAO.columns:
    if not months == 'Year':
        plt.plot(dfNAO['Year'],dfNAO[months], "-o", label=str(months))
        
ax.set_xlabel('Year', fontsize=16)
ax.set_ylabel("North Atlantic Oscillation Index", fontsize=16)
ax.set_title("North Atlantic Oscillation (2000-present)", fontsize=24)
ax.legend(loc='best', prop={'size': 20})

# %%
dec = dfNAO['Dec']
jan = dfNAO['Jan']
feb = dfNAO['Feb']

a=statistics.mean(dec)
b=statistics.mean(jan)
c=statistics.mean(feb)

NAO_means= np.array([a,b,c])
NAO_means= pd.Series(NAO_means, index=["Dec","Jan","Feb"])

#seaborn.barplot(data=NAO_means,x=index, y="Mean NAO")

NAO_means
# Out:
# Dec    0.404545
# Jan    0.432727
# Feb    0.485455
# dtype: float64

# %% [markdown]
# ## Ocean Data: Sea Surface Height and Ocean Mixed Layer Thickness

# %% [markdown]
# I'm interested in the effects that NAO has on oceans.

# %%
ds_url_ocean = 'https://rda.ucar.edu/thredds/dodsC/files/g/ds650.0/soda3_5dy_ocean_reg/2010_2019/soda3_5dy_ocean_reg_2015_01_04.nc'
HOME = str(Path.home())
credFile = open(HOME+'/.rdarc','r')
userId, pw = credFile.read().split()

session = requests.Session()
session.auth = (userId, pw)
store_ocean = xr.backends.PydapDataStore.open(ds_url_ocean, session=session)

# %%
dsOcean = xr.open_dataset(store_ocean)
dsOcean
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 1, xt_ocean: 720, yt_ocean: 330, xu_ocean: 720, yu_ocean: 330, st_ocean: 50, sw_ocean: 50)
# Coordinates:
#   * time             (time) datetime64[ns] 2015-01-04T13:00:00
#   * xt_ocean         (xt_ocean) float64 0.25 0.75 1.25 ... 358.8 359.2 359.8
#   * yt_ocean         (yt_ocean) float64 -74.75 -74.25 -73.75 ... 89.25 89.75
#   * xu_ocean         (xu_ocean) float64 0.5 1.0 1.5 2.0 ... 359.0 359.5 360.0
#   * yu_ocean         (yu_ocean) float64 -74.5 -74.0 -73.5 ... 89.0 89.5 90.0
#   * st_ocean         (st_ocean) float64 5.034 15.1 25.22 ... 5.185e+03 5.395e+03
#   * sw_ocean         (sw_ocean) float64 5.034 15.1 25.22 ... 5.185e+03 5.395e+03
# Data variables: (12/26)
#     temp             (time, st_ocean, yt_ocean, xt_ocean) float32 ...
#     salt             (time, st_ocean, yt_ocean, xt_ocean) float32 ...
#     wt               (time, sw_ocean, yt_ocean, xt_ocean) float32 ...
#     ssh              (time, yt_ocean, xt_ocean) float32 ...
#     mlt              (time, yt_ocean, xt_ocean) float32 ...
#     mlp              (time, yt_ocean, xt_ocean) float32 ...
#     ...               ...
#     hflux_total_std  (time, yt_ocean, xt_ocean) float32 ...
#     prho_std         (time, st_ocean, yt_ocean, xt_ocean) float32 ...
#     u_std            (time, st_ocean, yu_ocean, xu_ocean) float32 ...
#     v_std            (time, st_ocean, yu_ocean, xu_ocean) float32 ...
#     taux_std         (time, yu_ocean, xu_ocean) float32 ...
#     tauy_std         (time, yu_ocean, xu_ocean) float32 ...
# Attributes:
#     CDI:                             Climate Data Interface version 1.9.2 (ht...
#     Conventions:                     CF-1.6
#     history:                         combines up to six soda3 ensemble member...
#     filename:                        soda3_5dy_ocean_reg_2015_01_04.nc
#     title:                           soda3 ensemble mean and standard deviati...
#     grid_type:                       mosaic
#     grid_tile:                       1
#     CDO:                             Climate Data Operators version 1.9.2 (ht...
#     DODS_EXTRA.Unlimited_Dimension:  time

# %% [markdown]
# Subsetting data:

# %%
# Areal extent
lonW = -80.25
lonE = -30.25
latS = 30.25
latN = 60.25
latRange = np.arange(latS-5,latN+5,.5)
lonRange = np.arange((lonW-5+360),(lonE+5+360),.5)

# Date/Time specification
Year = 2015
Month = 1
Day = 4
Hour = 13
Minute = 0
dateTime = dt(Year,Month,Day, Hour, Minute)
timeStr = dateTime.strftime("%Y-%m-%d %H%M UTC")

# %% [markdown]
# Selecting variables: I'm interested in ocean mixed layer thickness (mlt) and sea surface height (ssh)

# %%
mlt = dsOcean['mlt'].sel(time=dateTime,yt_ocean=latRange,xt_ocean=lonRange)
ssh = dsOcean['ssh'].sel(time=dateTime,yt_ocean=latRange,xt_ocean=lonRange)

# %% [markdown]
# Checking dimensions for reference

# %%
print(mlt.shape)
print(mlt.units)
print(ssh.shape)
print(ssh.units)
# Out:
# (80, 120)
# m
# (80, 120)
# meter

# %% [markdown]
# ## Sea Surface Height and Ocean Mixed Layer Visualization

# %% [markdown]
# Onto the mapping! First setting up projections. I personally like the Robinson.

# %%
lats=mlt.yt_ocean
lons=mlt.xt_ocean

proj_map = ccrs.Robinson(central_longitude=-50.25)
proj_data = ccrs.Robinson() # Our data is lat-lon; thus its native projection is Plate Carree.
res = '50m'

# %% [markdown]
# Doing some calculations to determine values

# %%
print(mlt.min())
print(mlt.max())
print(ssh.min())
print(ssh.max())
# Out:
# <xarray.DataArray 'mlt' ()>
# array(5.96886873)
# Coordinates:
#     time     datetime64[ns] 2015-01-04T13:00:00
# <xarray.DataArray 'mlt' ()>
# array(1734.51367188)
# Coordinates:
#     time     datetime64[ns] 2015-01-04T13:00:00
# <xarray.DataArray 'ssh' ()>
# array(-1.08821058)
# Coordinates:
#     time     datetime64[ns] 2015-01-04T13:00:00
# <xarray.DataArray 'ssh' ()>
# array(0.48811862)
# Coordinates:
#     time     datetime64[ns] 2015-01-04T13:00:00

# %% [markdown]
# Setting up intervals for contours

# %%
minZ = 10
maxZ = 1730
cint = 50
mltints = np.arange(minZ,maxZ,cint)
print(mltints)

minZ = -1.088
maxZ = 0.485
cint = 0.05
sshints = np.arange(minZ,maxZ,cint)
sshints
# Out:
# [  10   60  110  160  210  260  310  360  410  460  510  560  610  660
#   710  760  810  860  910  960 1010 1060 1110 1160 1210 1260 1310 1360
#  1410 1460 1510 1560 1610 1660 1710]
# <xarray.DataArray 'mlt' (yt_ocean: 80, xt_ocean: 120)>
# array([[ 67.14139 ,  47.502693,  44.27507 , ...,  96.3757  ,  90.80385 ,
#          89.38677 ],
#        [ 58.52648 ,  52.131187,  46.791447, ...,  97.674965,  95.53805 ,
#          97.74706 ],
#        [ 59.111378,  58.797096,  54.908176, ..., 103.747154, 102.721436,
#         102.190414],
#        ...,
#        [       nan,        nan,  35.13951 , ..., 393.35132 , 321.8663  ,
#         280.68677 ],
#        [       nan,        nan,        nan, ..., 283.31366 , 230.23488 ,
#         218.67682 ],
#        [       nan,        nan,        nan, ..., 216.10432 , 188.0658  ,
#         187.28365 ]], dtype=float32)
# Coordinates:
#     time      datetime64[ns] 2015-01-04T13:00:00
#   * xt_ocean  (xt_ocean) float64 274.8 275.2 275.8 276.2 ... 333.2 333.8 334.2
#   * yt_ocean  (yt_ocean) float64 25.25 25.75 26.25 26.75 ... 63.75 64.25 64.75
# Attributes:
#     standard_name:  ocean_mixed_layer_thickness_defined_by_temperature
#     long_name:      ocean_mixed_layer_thickness_defined_by_temperature
#     units:          m
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     name:           mlt

# %%
fig = plt.figure(figsize=(24,16))
ax = plt.subplot(1,1,1,projection=proj_map)
ax.set_extent ([lonW,lonE,latS,latN])
ax.add_feature(cfeature.COASTLINE.with_scale(res))

mlt_lines = ax.contour(lons,lats,mlt,mltints,transform=proj_data,linewidths=1.25,colors='green')
ax.clabel(mlt_lines, inline_spacing=0.2, fontsize=11, fmt='%.0f')
title = plt.title("Ocean Mixed Layer and Sea Surface Heights on "+timeStr,fontsize=16)

# %% [markdown]
# # [DELETE THIS] Arctic Sea Ice

# %% [markdown]
# The data I used for this section is found here: https://rda.ucar.edu/data/ds233.5/winter_latlon.txt
#
# First, change text file to csv (dataframe). To change my methods from last time, I manually edited the text file in the Linux terminal to have Column Labels.

# %%
#ASI_url = "https://rda.ucar.edu/data/ds233.5/winter_latlon.txt"

#HOME = str(Path.home())
#credFile = open(HOME+'/.rdarc','r')
#userId, pw = credFile.read().split()

#session = requests.Session()
#session.auth = (userId, pw)
#ASI_txt = xr.backends.PydapDataStore.open(ASI_url, session=session)

#ASI_df = pd.read_csv(ASI_txt, sep='\s+')

#dfASI = pd.read_csv(filepath_or_buffer='https://rda.ucar.edu/data/ds233.5/winter_latlon.txt')

# I keep getting the 403 Forbidden error, so I'm just going to download the text file into my HW folder...

dfASI = pd.read_csv('/home11/ugrad/2020/ss484272/atm533/hw/final/winter_latlon.txt', sep='\s+')
dfASI.to_csv('/home11/ugrad/2020/ss484272/atm533/hw/final/winter_latlon.csv')

print(dfASI)
print(dfASI.shape)
# Out:
#       longitude  latitude  thickness
# 0        -179.5      89.5        3.0
# 1        -178.5      89.5        3.0
# 2        -177.5      89.5        3.0
# 3        -176.5      89.5        3.0
# 4        -175.5      89.5        3.0
# ...         ...       ...        ...
# 8995      175.5      65.5      168.0
# 8996      176.5      65.5      168.0
# 8997      177.5      65.5      168.0
# 8998      178.5      65.5      168.0
# 8999      179.5      65.5      168.0
#
# [9000 rows x 3 columns]
# (9000, 3)

# %% [markdown]
# Slice rows to shorten data

# %%
#dfASI=dfASI.iloc[::3]
dfASI
# Out:
#       longitude  latitude  thickness
# 0        -179.5      89.5        3.0
# 1        -178.5      89.5        3.0
# 2        -177.5      89.5        3.0
# 3        -176.5      89.5        3.0
# 4        -175.5      89.5        3.0
# ...         ...       ...        ...
# 8995      175.5      65.5      168.0
# 8996      176.5      65.5      168.0
# 8997      177.5      65.5      168.0
# 8998      178.5      65.5      168.0
# 8999      179.5      65.5      168.0
#
# [9000 rows x 3 columns]

# %% [markdown]
# ### Arctic Sea Ice -- Map

# %% [markdown]
# Now that the dataframe is ready, I can start turning this into a map.

# %%
lons = dfASI['longitude']
lats = dfASI['latitude']
thickness = dfASI['thickness']

lons
thickness.shape
# Out:
# (9000,)

# %%
ax = plt.axes(projection=ccrs.Robinson(central_longitude=180))

proj_map = ccrs.Robinson()
proj_data = ccrs.Robinson()

ax.gridlines()

fig = plt.figure(figsize=(18,12))
ax = plt.subplot(1,1,1,projection=proj_map)
ax.set_extent ([-180,0,-90,90])
ax.add_feature(cfeature.COASTLINE.with_scale(res))
CF = ax.contourf(lons,lats,thickness, transform=proj_data,cmap=plt.get_cmap('coolwarm'))
cbar = plt.colorbar(CF,shrink=0.5)
cbar.ax.tick_params(labelsize=16)
cbar.ax.set_ylabel("Height (dam)",fontsize=16)


#ax.pcolor(lons,lats,thickness,cmap='winter')

#ax.scatter(lons,lats,c=thickness,cmap='coolwarm')


#dfASI.thickness.plot();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_23820/582464948.py in <module>
#      10 ax.set_extent ([-180,0,-90,90])
#      11 ax.add_feature(cfeature.COASTLINE.with_scale(res))
# ---> 12 CF = ax.contourf(lons,lats,thickness, transform=proj_data,cmap=plt.get_cmap('coolwarm'))
#      13 cbar = plt.colorbar(CF,shrink=0.5)
#      14 cbar.ax.tick_params(labelsize=16)
#
# /knight/anaconda_jan21/envs/aug21/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py in wrapper(self, *args, **kwargs)
#     316
#     317         kwargs['transform'] = transform
# --> 318         return func(self, *args, **kwargs)
#     319     return wrapper
#     320
#
# /knight/anaconda_jan21/envs/aug21/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py in wrapper(self, *args, **kwargs)
#     360             # Use the new points as the input arguments
#     361             args = (x, y, z) + args[3:]
# --> 362         return func(self, *args, **kwargs)
#     363     return wrapper
#     364
#
# /knight/anaconda_jan21/envs/aug21/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py in contourf(self, *args, **kwargs)
#    1712                         sub_trans.force_path_ccw = True
#    1713
# -> 1714         result = matplotlib.axes.Axes.contourf(self, *args, **kwargs)
#    1715
#    1716         # We need to compute the dataLim correctly for contours.
#
# /knight/anaconda_jan21/envs/aug21/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# /knight/anaconda_jan21/envs/aug21/lib/python3.8/site-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6432     def contourf(self, *args, **kwargs):
#    6433         kwargs['filled'] = True
# -> 6434         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6435         self._request_autoscale_view()
#    6436         return contours
#
# /knight/anaconda_jan21/envs/aug21/lib/python3.8/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, *args, **kwargs)
#     775         self._transform = transform
#     776
# --> 777         kwargs = self._process_args(*args, **kwargs)
#     778         self._process_levels()
#     779
#
# /knight/anaconda_jan21/envs/aug21/lib/python3.8/site-packages/matplotlib/contour.py in _process_args(self, corner_mask, *args, **kwargs)
#    1364             self._corner_mask = corner_mask
#    1365
# -> 1366             x, y, z = self._contour_args(args, kwargs)
#    1367
#    1368             _mask = ma.getmask(z)
#
# /knight/anaconda_jan21/envs/aug21/lib/python3.8/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1422             args = args[1:]
#    1423         elif Nargs <= 4:
# -> 1424             x, y, z = self._check_xyz(args[:3], kwargs)
#    1425             args = args[3:]
#    1426         else:
#
# /knight/anaconda_jan21/envs/aug21/lib/python3.8/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1450
#    1451         if z.ndim != 2:
# -> 1452             raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1453         if z.shape[0] < 2 or z.shape[1] < 2:
#    1454             raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#
# TypeError: Input z must be 2D, not 1D

# %%
gdfASI = geopandas.GeoDataFrame(dfASI, geometry=geopandas.points_from_xy(lons,lats))

ax = plt.axes(projection=ccrs.Robinson(central_longitude=180))
ax.coastlines()
ax.gridlines()

gdfASI.plot(ax=ax,cmap='coolwarm')
# Out:
# <GeoAxesSubplot:>

# %%
dfASI
# Out:
#       longitude  latitude  thickness                     geometry
# 0        -179.5      89.5        3.0  POINT (-179.50000 89.50000)
# 1        -178.5      89.5        3.0  POINT (-178.50000 89.50000)
# 2        -177.5      89.5        3.0  POINT (-177.50000 89.50000)
# 3        -176.5      89.5        3.0  POINT (-176.50000 89.50000)
# 4        -175.5      89.5        3.0  POINT (-175.50000 89.50000)
# ...         ...       ...        ...                          ...
# 8995      175.5      65.5      168.0   POINT (175.50000 65.50000)
# 8996      176.5      65.5      168.0   POINT (176.50000 65.50000)
# 8997      177.5      65.5      168.0   POINT (177.50000 65.50000)
# 8998      178.5      65.5      168.0   POINT (178.50000 65.50000)
# 8999      179.5      65.5      168.0   POINT (179.50000 65.50000)
#
# [9000 rows x 4 columns]
